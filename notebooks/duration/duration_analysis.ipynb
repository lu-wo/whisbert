# %%
from src.utils.analysis import LanguageModelAnalyzer

# %%
PREDICTION_PATH = "/Users/lukas/Desktop/projects/MIT/MIT_prosody/precomputed/predictions/duration/pred_bert_cased"

# %%
analyzer = LanguageModelAnalyzer(dir_path=PREDICTION_PATH, batch_analysis=True)
# Out:
# all lengths 69 69 69 69 69 69

# %%
analyzer.compute_mse_over_dataset()
# Out:
# 0.006102237

# %%
id = 10

text = analyzer.input_texts[id][0].split(" ")
labels = analyzer.original_labels[id][0]

bert_preds = analyzer.get_pred(id)[0][analyzer.get_loss_mask(id)[0] == 1]

len(text), len(labels), len(bert_preds)
# Out:
# (19, 19, 19)

# %%
from src.utils.plots import plot_ground_truth_and_predictions

plot_ground_truth_and_predictions(text, labels, [bert_preds], ["BERT"])
