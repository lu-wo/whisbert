# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
table = table_data = {
    "Prominence": {
        "entropy": 1.034,
        "models": {
            "fastText": 0.785,
            "GloVe": 0.801,
            "Causal": 0.664,
            "Bidirectional": 0.613,
        },
    },
    "Prominence (rel. prev.)": {
        "entropy": 1.380,
        "models": {
            "fastText": 1.154,
            "GloVe": 1.194,
            "Causal": 0.924,
            "Bidirectional": 0.878,
        },
    },
    "Prominence (rel. mean)": {
        "entropy": 0.817,
        "models": {
            "fastText": 0.794,
            "GloVe": 0.830,
            "Causal": 0.724,
            "Bidirectional": 0.642,
        },
    },
    "Energy": {
        "entropy": 0.797,
        "models": {
            "fastText": 0.749,
            "GloVe": 0.758,
            "Causal": 0.617,
            "Bidirectional": 0.497,
        },
    },
    "Duration": {
        "entropy": -0.935,
        "models": {
            "fastText": -1.416,
            "GloVe": -1.355,
            "Causal": -1.506,
            "Bidirectional": -1.657,
        },
    },
    "Pitch": {
        "entropy": 9.312,
        "models": {
            "fastText": 9.662,  # TODO: put real values
            "GloVe": 9.883,  # TODO: put real values
            "Causal": 3.089,
            "Bidirectional": 2.595,
        },
    },
    "Pause": {
        "entropy": -2.938,
        "models": {
            "fastText": -1.423,
            "GloVe": -1.420,
            "Causal": -1.658,
            "Bidirectional": -2.519,
        },
    },
}

# %%
from src.utils.plots import plot_mutual_info

plot_mutual_info(table, log_scale=True)
