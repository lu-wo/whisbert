# %%
import matplotlib.pyplot as plt
import numpy as np
from src.utils.plots import plot_bars

# Use the function
plot_bars(
    entropy=0.228,
    surprisal=0.148,
    title="Prominence vs. Entropy and Surprisal",
)
